# %%
import pandas as pd
penguins = pd.read_csv('/Users/DeepDhindsa/Desktop/COSC4426/penguins.csv')
penguins
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    MALE
# 1         3800.0  FEMALE
# ...

# %%
import seaborn as sea
sea.set(style="ticks", color_codes=True)
p1= sea.load_dataset("penguins")
g1 = sea.pairplot(penguins)

import matplotlib.pyplot as plt
plt.show()

# %%
sea.scatterplot(data = p1, x="bill_depth_mm", y="body_mass_g")
# Out:
# <Axes: xlabel='bill_depth_mm', ylabel='body_mass_g'>

# %%
sea.scatterplot(data = p1, x="bill_depth_mm", y="flipper_length_mm")
# Out:
# <Axes: xlabel='bill_depth_mm', ylabel='flipper_length_mm'>

# %%
p1
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
class1= p1[["bill_length_mm", "bill_depth_mm", "species"]]
class1
# Out:
#      bill_length_mm  bill_depth_mm species
# 0              39.1           18.7  Adelie
# 1              39.5           17.4  Adelie
# 2              40.3           18.0  Adelie
# 3               NaN            NaN  Adelie
# 4              36.7           19.3  Adelie
# ..              ...            ...     ...
# 339             NaN            NaN  Gentoo
# 340            46.8           14.3  Gentoo
# 341            50.4           15.7  Gentoo
# 342            45.2           14.8  Gentoo
# 343            49.9           16.1  Gentoo
#
# [344 rows x 3 columns]

# %%
classification_figure1 = sea.pairplot(class1)
classification_figure1.fig.set_size_inches(9,6.5)

# %%
classification_figure1 = sea.pairplot(class1, hue="species")
classification_figure1.fig.set_size_inches(9,6.5)

# %%
f1, axs = plt.subplots(1,2, figsize=(8,4), gridspec_kw=dict(width_ratios=[4,3]))
sea.scatterplot(data=p1, x="flipper_length_mm", y="bill_length_mm", hue="species", ax=axs[0])
sea.histplot(data=p1, x="flipper_length_mm", hue="species", shrink=.8, legend=False, ax=axs[1])
f1.tight_layout()

# %%
sea.displot(data=p1, x="flipper_length_mm", hue="species", multiple="stack")

# %%
sea.displot(data=p1, x="flipper_length_mm", hue="species", multiple="stack", kind="kde")

# %%
sea.displot(data=p1, x="flipper_length_mm", hue="species", col="species")

# %%
sea.jointplot(data=p1, x="flipper_length_mm", y="bill_length_mm")

# %%
p2=p1.dropna()
p2
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 4    Adelie  Torgersen            36.7           19.3              193.0
# 5    Adelie  Torgersen            39.3           20.6              190.0
# ..      ...        ...             ...            ...                ...
# 338  Gentoo     Biscoe            47.2           13.7              214.0
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
import numpy as np
import scipy.stats
x=p2.flipper_length_mm
y=p2.bill_length_mm
z=scipy.stats.pearsonr(x,y)
z
# Out:
# PearsonRResult(statistic=0.6530956386670858, pvalue=7.211340708098312e-42)

# %%
p3=p2[["bill_length_mm", "bill_depth_mm"]]
p3
# Out:
#      bill_length_mm  bill_depth_mm
# 0              39.1           18.7
# 1              39.5           17.4
# 2              40.3           18.0
# 4              36.7           19.3
# 5              39.3           20.6
# ..              ...            ...
# 338            47.2           13.7
# 340            46.8           14.3
# 341            50.4           15.7
# 342            45.2           14.8
# 343            49.9           16.1
#
# [333 rows x 2 columns]

# %%
p3.plot()
# Out:
# <Axes: >

# %%
import pandas as pd
p100 = pd.read_csv('/Users/DeepDhindsa/Desktop/COSC4426/PalmerPenguins.csv')
p100.head(5)
# Out:
#   studyName  Sample Number                              Species  Region  \
# 0   PAL0708              1  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 1   PAL0708              2  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 2   PAL0708              3  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 3   PAL0708              4  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 4   PAL0708              5  Adelie Penguin (Pygoscelis adeliae)  Anvers
#
#       Island               Stage Individual ID Clutch Completion    Date Egg  \
# 0  Torgersen  Adult, 1 Egg Stage          N1A1               Yes  2007-11-11
# 1  Torgersen  Adult, 1 Egg Stage          N1A2               Yes  2007-11-11
# 2  Torgersen  Adult, 1 Egg Stage          N2A1               Yes  2007-11-16
# 3  Torgersen  Adult, 1 Egg Stage          N2A2               Yes  2007-11-16
# 4  Torgersen  Adult, 1 Egg Stage          N3A1               Yes  2007-11-16
#
# ...

# %%
p100.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   studyName            344 non-null    object
#  1   Sample Number        344 non-null    int64
#  2   Species              344 non-null    object
#  3   Region               344 non-null    object
#  4   Island               344 non-null    object
#  5   Stage                344 non-null    object
#  6   Individual ID        344 non-null    object
#  7   Clutch Completion    344 non-null    object
#  8   Date Egg             344 non-null    object
#  9   Culmen Length (mm)   342 non-null    float64
#  10  Culmen Depth (mm)    342 non-null    float64
#  11  Flipper Length (mm)  342 non-null    float64
#  12  Body Mass (g)        342 non-null    float64
#  13  Sex                  333 non-null    object
#  14  Delta 15 N (o/oo)    330 non-null    float64
# ...

# %%
# !pip install palmerpenguins

# %%
p500 = pd.read_csv('/Users/DeepDhindsa/Desktop/COSC4426/PalmerPenguins.csv')
p500
# Out:
#     studyName  Sample Number                                    Species  \
# 0     PAL0708              1        Adelie Penguin (Pygoscelis adeliae)
# 1     PAL0708              2        Adelie Penguin (Pygoscelis adeliae)
# 2     PAL0708              3        Adelie Penguin (Pygoscelis adeliae)
# 3     PAL0708              4        Adelie Penguin (Pygoscelis adeliae)
# 4     PAL0708              5        Adelie Penguin (Pygoscelis adeliae)
# ..        ...            ...                                        ...
# 339   PAL0910             64  Chinstrap penguin (Pygoscelis antarctica)
# 340   PAL0910             65  Chinstrap penguin (Pygoscelis antarctica)
# 341   PAL0910             66  Chinstrap penguin (Pygoscelis antarctica)
# 342   PAL0910             67  Chinstrap penguin (Pygoscelis antarctica)
# 343   PAL0910             68  Chinstrap penguin (Pygoscelis antarctica)
#
#      Region     Island               Stage Individual ID Clutch Completion  \
# ...

# %%
p500.head(5)
# Out:
#   studyName  Sample Number                              Species  Region  \
# 0   PAL0708              1  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 1   PAL0708              2  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 2   PAL0708              3  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 3   PAL0708              4  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 4   PAL0708              5  Adelie Penguin (Pygoscelis adeliae)  Anvers
#
#       Island               Stage Individual ID Clutch Completion    Date Egg  \
# 0  Torgersen  Adult, 1 Egg Stage          N1A1               Yes  2007-11-11
# 1  Torgersen  Adult, 1 Egg Stage          N1A2               Yes  2007-11-11
# 2  Torgersen  Adult, 1 Egg Stage          N2A1               Yes  2007-11-16
# 3  Torgersen  Adult, 1 Egg Stage          N2A2               Yes  2007-11-16
# 4  Torgersen  Adult, 1 Egg Stage          N3A1               Yes  2007-11-16
#
# ...

# %%
p500.isna().sum()
# Out:
# studyName                0
# Sample Number            0
# Species                  0
# Region                   0
# Island                   0
# Stage                    0
# Individual ID            0
# Clutch Completion        0
# Date Egg                 0
# Culmen Length (mm)       2
# Culmen Depth (mm)        2
# Flipper Length (mm)      2
# Body Mass (g)            2
# Sex                     11
# Delta 15 N (o/oo)       14
# Delta 13 C (o/oo)       13
# Comments               290
# dtype: int64

# %%
p4= p500.dropna()
p4
# Out:
#     studyName  Sample Number                                    Species  \
# 6     PAL0708              7        Adelie Penguin (Pygoscelis adeliae)
# 7     PAL0708              8        Adelie Penguin (Pygoscelis adeliae)
# 28    PAL0708             29        Adelie Penguin (Pygoscelis adeliae)
# 29    PAL0708             30        Adelie Penguin (Pygoscelis adeliae)
# 38    PAL0708             39        Adelie Penguin (Pygoscelis adeliae)
# 68    PAL0809             69        Adelie Penguin (Pygoscelis adeliae)
# 69    PAL0809             70        Adelie Penguin (Pygoscelis adeliae)
# 120   PAL0910            121        Adelie Penguin (Pygoscelis adeliae)
# 121   PAL0910            122        Adelie Penguin (Pygoscelis adeliae)
# 130   PAL0910            131        Adelie Penguin (Pygoscelis adeliae)
# 131   PAL0910            132        Adelie Penguin (Pygoscelis adeliae)
# 138   PAL0910            139        Adelie Penguin (Pygoscelis adeliae)
# ...

# %%
p4.head(5)
# Out:
#    studyName  Sample Number                              Species  Region  \
# 6    PAL0708              7  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 7    PAL0708              8  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 28   PAL0708             29  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 29   PAL0708             30  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 38   PAL0708             39  Adelie Penguin (Pygoscelis adeliae)  Anvers
#
#        Island               Stage Individual ID Clutch Completion    Date Egg  \
# 6   Torgersen  Adult, 1 Egg Stage          N4A1                No  2007-11-15
# 7   Torgersen  Adult, 1 Egg Stage          N4A2                No  2007-11-15
# 28     Biscoe  Adult, 1 Egg Stage         N18A1                No  2007-11-10
# 29     Biscoe  Adult, 1 Egg Stage         N18A2                No  2007-11-10
# 38      Dream  Adult, 1 Egg Stage         N25A1                No  2007-11-13
#
# ...

# %%
import sklearn as learn
import matplotlib as mplt
import matplotlib.pyplot as plt
mplt.rc('axes', labelsize =14)
mplt.rc('xtick', labelsize =12)
mplt.rc('ytick', labelsize =12)

# %%
p4['Region'].value_counts()
# Out:
# Anvers    34
# Name: Region, dtype: int64

# %%
p500d=p500.describe()
p500d
# Out:
#        Sample Number  Culmen Length (mm)  Culmen Depth (mm)  \
# count     344.000000          342.000000         342.000000
# mean       63.151163           43.921930          17.151170
# std        40.430199            5.459584           1.974793
# min         1.000000           32.100000          13.100000
# 25%        29.000000           39.225000          15.600000
# 50%        58.000000           44.450000          17.300000
# 75%        95.250000           48.500000          18.700000
# max       152.000000           59.600000          21.500000
#
#        Flipper Length (mm)  Body Mass (g)  Delta 15 N (o/oo)  \
# count           342.000000     342.000000         330.000000
# mean            200.915205    4201.754386           8.733382
# std              14.061714     801.954536           0.551770
# min             172.000000    2700.000000           7.632200
# 25%             190.000000    3550.000000           8.299890
# ...

# %%
p500t=p500.transpose()
p500t
# Out:
#                                                      0    \
# studyName                                        PAL0708
# Sample Number                                          1
# Species              Adelie Penguin (Pygoscelis adeliae)
# Region                                            Anvers
# Island                                         Torgersen
# Stage                                 Adult, 1 Egg Stage
# Individual ID                                       N1A1
# Clutch Completion                                    Yes
# Date Egg                                      2007-11-11
# Culmen Length (mm)                                  39.1
# Culmen Depth (mm)                                   18.7
# Flipper Length (mm)                                181.0
# Body Mass (g)                                     3750.0
# Sex                                                 MALE
# Delta 15 N (o/oo)                                    NaN
# ...

# %%
p500.corr()
# Out:
# /var/folders/ph/4c0b8k752x76ktp3_7gxdq380000gn/T/ipykernel_94849/118488040.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   p500.corr()
#                      Sample Number  Culmen Length (mm)  Culmen Depth (mm)  \
# Sample Number             1.000000           -0.236356          -0.022352
# Culmen Length (mm)       -0.236356            1.000000          -0.235053
# Culmen Depth (mm)        -0.022352           -0.235053           1.000000
# Flipper Length (mm)       0.040849            0.656181          -0.583851
# Body Mass (g)            -0.007042            0.595110          -0.471916
# Delta 15 N (o/oo)         0.006952           -0.059759           0.605874
# Delta 13 C (o/oo)        -0.488690            0.189025           0.429933
#
# ...

# %%
p501 = pd.read_csv('/Users/DeepDhindsa/Desktop/COSC4426/PalmerPenguins.csv')
p501
# Out:
#     studyName  Sample Number                                    Species  \
# 0     PAL0708              1        Adelie Penguin (Pygoscelis adeliae)
# 1     PAL0708              2        Adelie Penguin (Pygoscelis adeliae)
# 2     PAL0708              3        Adelie Penguin (Pygoscelis adeliae)
# 3     PAL0708              4        Adelie Penguin (Pygoscelis adeliae)
# 4     PAL0708              5        Adelie Penguin (Pygoscelis adeliae)
# ..        ...            ...                                        ...
# 339   PAL0910             64  Chinstrap penguin (Pygoscelis antarctica)
# 340   PAL0910             65  Chinstrap penguin (Pygoscelis antarctica)
# 341   PAL0910             66  Chinstrap penguin (Pygoscelis antarctica)
# 342   PAL0910             67  Chinstrap penguin (Pygoscelis antarctica)
# 343   PAL0910             68  Chinstrap penguin (Pygoscelis antarctica)
#
#      Region     Island               Stage Individual ID Clutch Completion  \
# ...

# %%
p501.drop(columns=['Comments', 'Stage'], inplace=True)
p501
# Out:
#     studyName  Sample Number                                    Species  \
# 0     PAL0708              1        Adelie Penguin (Pygoscelis adeliae)
# 1     PAL0708              2        Adelie Penguin (Pygoscelis adeliae)
# 2     PAL0708              3        Adelie Penguin (Pygoscelis adeliae)
# 3     PAL0708              4        Adelie Penguin (Pygoscelis adeliae)
# 4     PAL0708              5        Adelie Penguin (Pygoscelis adeliae)
# ..        ...            ...                                        ...
# 339   PAL0910             64  Chinstrap penguin (Pygoscelis antarctica)
# 340   PAL0910             65  Chinstrap penguin (Pygoscelis antarctica)
# 341   PAL0910             66  Chinstrap penguin (Pygoscelis antarctica)
# 342   PAL0910             67  Chinstrap penguin (Pygoscelis antarctica)
# 343   PAL0910             68  Chinstrap penguin (Pygoscelis antarctica)
#
#      Region     Island Individual ID Clutch Completion    Date Egg  \
# ...

# %%
plt.figure(figsize=(15,12))
sea.countplot(x=p501['Species'], alpha=0.65, saturation=0.85)
plt.title('Species Distributions', size=13, y =1.01)
plt.xlabel("")
plt.tick_params(axis='both', labelsize=12)

# %%
sea.set_theme(style="white")
g1=sea.relplot(data=p500, alpha=0.6,
              x='Culmen Length(mm)', y='Culmen Depth(mm)', hue="Island", size="Body Mass(g)", palette="Set1", sizes =(40,250), height =7)
g1.despine(left=True, bottom=True)
g1.set_axis_labels("Bill Length", "Bill Depth")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[47], line 2
#       1 sea.set_theme(style="white")
# ----> 2 g1=sea.relplot(data=p500, alpha=0.6,
#       3               x='Culmen Length(mm)', y='Culmen Depth(mm)', hue="Island", size="Body Mass(g)", palette="Set1", sizes =(40,250), height =7)
#       4 g1.despine(left=True, bottom=True)
#       5 g1.set_axis_labels("Bill Length", "Bill Depth")
#
# File ~/anaconda3/lib/python3.10/site-packages/seaborn/relational.py:862, in relplot(data, x, y, hue, size, style, units, row, col, col_wrap, row_order, col_order, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, dashes, style_order, legend, kind, height, aspect, facet_kws, **kwargs)
#     859     kwargs.pop("ax")
#     861 # Use the full dataset to map the semantics
# --> 862 p = plotter(
#     863     data=data,
# ...

# %%
ax1 = plt.figure(figsize= (13,12))
ax1= sea.boxplot(data =p500, x='Species', y='Body Mass (g)',palette ="Set2")

ax1.set_ylabel('Body Mass(g)')
ax1.set_xlabel("")
ax1.set_title('Body Mass by Species')
ax1.tick_params(axis='x', labelsize=12)

# %%
g1=plt.figure(figsize=(16,16))
g1=sea.catplot(data=p500, kind="bar", x='Species', y='Body Mass (g)', hue="Sex", ci="sd", palette="dark", alpha=.6, height =10)
g1.despine(left=True)
g1.set_axis_labels("", "Body Mass (g)")
g1.legend.set_title("")
# Out:
# /var/folders/ph/4c0b8k752x76ktp3_7gxdq380000gn/T/ipykernel_94849/165815042.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   g1=sea.catplot(data=p500, kind="bar", x='Species', y='Body Mass (g)', hue="Sex", ci="sd", palette="dark", alpha=.6, height =10)
